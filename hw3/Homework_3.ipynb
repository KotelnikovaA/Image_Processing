# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import copy
import math

# %% [markdown]
# # 1. Для изображения sar_3.jpg найти наиболее протяженный участок (выделить линии при помощи преобразования Хафа)

# %%
image = cv2.imread('sar_3.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
plt.imshow(image)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5))

# %%
bin_img = copy.deepcopy(image_gray)
threshold_value = 80
bin_img[image_gray < threshold_value] = 0
bin_img[image_gray >= threshold_value] = 255

canny = cv2.Canny(bin_img, 0,250, apertureSize = 3)
lines = cv2.HoughLines(canny, 1, np.pi / 180, 110)

if lines is not None:
    for i in range(0, len(lines)):
        rho = lines[i][0][0]
        theta = lines[i][0][1]
        a = math.cos(theta)
        b = math.sin(theta)
        x0 = a * rho
        y0 = b * rho
        pt1 = (int(x0 + 1000*(-b)), int(y0 + 1000*(a)))
        pt2 = (int(x0 - 1000*(-b)), int(y0 - 1000*(a)))
        cv2.line(image, pt1, pt2, (255, 0, 0), 2, cv2.LINE_AA)
        
plt.imshow(image)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(224.5), np.float64(224.5), np.float64(-0.5))

# %% [markdown]
# # 2. Для изображения sar_3.jpg провести исследование алгоритмов бинаризации, выделить участок дорожной полосы.

# %% [markdown]
# Точечная бинаризация

# %%
bin_img = copy.deepcopy(image_gray)
T = 80
bin_img[image_gray < T] = 0
bin_img[image_gray >= T] = 255

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1); plt.imshow(image_gray, cmap='gray'); plt.title('Исходное изображение'); plt.axis('off')
plt.subplot(1, 2, 2); plt.imshow(bin_img, cmap='gray'); plt.title('Точечная бинаризация'); plt.axis('off')
plt.show()

# %% [markdown]
# Бинаризация Отсу

# %%
_,th2 = cv2.threshold(image_gray,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1); plt.imshow(image_gray, cmap='gray'); plt.title('Исходное изображение'); plt.axis('off')
plt.subplot(1, 2, 2); plt.imshow(th2, cmap='gray'); plt.title('Бинаризация Отсу'); plt.axis('off')
plt.show()

# %% [markdown]
# Адаптивная бинаризация

# %%
th3 = cv2.adaptiveThreshold(image_gray,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,191,25)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1); plt.imshow(image_gray, cmap='gray'); plt.title('Исходное изображение'); plt.axis('off')
plt.subplot(1, 2, 2); plt.imshow(th3, cmap='gray'); plt.title('Адаптивная бинаризация'); plt.axis('off')
plt.show()

# %% [markdown]
# Оператор Собеля

# %%
scale = 0.5
delta = 0
ddepth = cv2.CV_16S
grad_x = cv2.Sobel(image_gray, ddepth, 1, 0, ksize=3, scale=scale, delta=delta, borderType=cv2.BORDER_DEFAULT)
grad_y = cv2.Sobel(image_gray, ddepth, 0, 1, ksize=3, scale=scale, delta=delta, borderType=cv2.BORDER_DEFAULT)
grad = cv2.addWeighted(grad_x, 0.5, grad_y, 0.5,0.0)

plt.figure(figsize=(20, 5))
plt.subplot(1, 4, 1); plt.imshow(image_gray, cmap='gray'); plt.title('Исходное изображение'); plt.axis('off')
plt.subplot(1, 4, 2); plt.imshow((grad_x - grad_x.min())*255, cmap="gray"); plt.title('Нормализация по х'); plt.axis('off')
plt.subplot(1, 4, 3); plt.imshow((grad_y - grad_y.min())*255, cmap="gray"); plt.title('Нормализация по у'); plt.axis('off')
plt.subplot(1, 4, 4); plt.imshow((grad - grad.min())*255, cmap="gray"); plt.title('Оператор Собеля'); plt.axis('off')
plt.show()

# %% [markdown]
# Canny

# %%
edges = cv2.Canny(image_gray,150,300)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1); plt.imshow(image_gray, cmap='gray'); plt.title('Исходное изображение'); plt.axis('off')
plt.subplot(1, 2, 2); plt.imshow(edges, cmap='gray'); plt.title('Canny'); plt.axis('off')
plt.show()
